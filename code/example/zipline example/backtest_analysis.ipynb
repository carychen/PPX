# %%
import pandas as pd

# %%
perf = pd.read_pickle('buyappleout.pickle') # read in perf DataFrame
perf.head()
# Out:
#                              AAPL  algo_volatility  algorithm_period_return  \
# 2008-01-02 21:00:00+00:00  194.84              NaN             0.000000e+00
# 2008-01-03 21:00:00+00:00  194.93         0.000001            -1.000000e-07
# 2008-01-04 21:00:00+00:00  180.05         0.001364            -1.490000e-04
# 2008-01-07 21:00:00+00:00  177.64         0.001114            -1.973000e-04
# 2008-01-08 21:00:00+00:00  171.25         0.001398            -3.891000e-04
#
#                               alpha  benchmark_period_return  \
# 2008-01-02 21:00:00+00:00       NaN                -0.014438
# 2008-01-03 21:00:00+00:00 -0.000025                -0.014438
# 2008-01-04 21:00:00+00:00  0.005975                -0.038635
# 2008-01-07 21:00:00+00:00 -0.004636                -0.035536
# 2008-01-08 21:00:00+00:00 -0.006235                -0.053236
#
#                            benchmark_volatility      beta  capital_used  \
# 2008-01-02 21:00:00+00:00                   NaN       NaN           0.0
# 2008-01-03 21:00:00+00:00              0.162064 -0.000007      -19494.0
# 2008-01-04 21:00:00+00:00              0.195877  0.005646      -18006.0
# 2008-01-07 21:00:00+00:00              0.205311  0.003459      -17765.0
# 2008-01-08 21:00:00+00:00              0.189942  0.004905      -17126.0
#
#                            ending_cash  ending_exposure  \
# 2008-01-02 21:00:00+00:00   10000000.0              0.0
# 2008-01-03 21:00:00+00:00    9980506.0          19493.0
# 2008-01-04 21:00:00+00:00    9962500.0          36010.0
# 2008-01-07 21:00:00+00:00    9944735.0          53292.0
# 2008-01-08 21:00:00+00:00    9927609.0          68500.0
#
#                                     ...            short_exposure  \
# 2008-01-02 21:00:00+00:00           ...                         0
# 2008-01-03 21:00:00+00:00           ...                         0
# 2008-01-04 21:00:00+00:00           ...                         0
# 2008-01-07 21:00:00+00:00           ...                         0
# 2008-01-08 21:00:00+00:00           ...                         0
#
#                            short_value  shorts_count    sortino  \
# 2008-01-02 21:00:00+00:00            0             0        NaN
# 2008-01-03 21:00:00+00:00            0             0 -11.224972
# 2008-01-04 21:00:00+00:00            0             0  -9.171305
# 2008-01-07 21:00:00+00:00            0             0 -10.004320
# 2008-01-08 21:00:00+00:00            0             0 -11.157664
#
#                            starting_cash  starting_exposure  starting_value  \
# 2008-01-02 21:00:00+00:00     10000000.0                0.0             0.0
# 2008-01-03 21:00:00+00:00     10000000.0                0.0             0.0
# 2008-01-04 21:00:00+00:00      9980506.0            19493.0         19493.0
# 2008-01-07 21:00:00+00:00      9962500.0            36010.0         36010.0
# 2008-01-08 21:00:00+00:00      9944735.0            53292.0         53292.0
#
#                            trading_days  \
# 2008-01-02 21:00:00+00:00             1
# 2008-01-03 21:00:00+00:00             2
# 2008-01-04 21:00:00+00:00             3
# 2008-01-07 21:00:00+00:00             4
# 2008-01-08 21:00:00+00:00             5
#
#                                                                 transactions  \
# 2008-01-02 21:00:00+00:00                                                 []
# 2008-01-03 21:00:00+00:00  [{'order_id': 'd62dc8dda03844f886981cb56078946...
# 2008-01-04 21:00:00+00:00  [{'order_id': 'e33d88edf663409c83a7d89d0764150...
# 2008-01-07 21:00:00+00:00  [{'order_id': 'cce067203f024776b5924b78caf3530...
# 2008-01-08 21:00:00+00:00  [{'order_id': '273b147b62574f9faefdd15bc334156...
#
#                            treasury_period_return
# 2008-01-02 21:00:00+00:00                  0.0391
# 2008-01-03 21:00:00+00:00                  0.0391
# 2008-01-04 21:00:00+00:00                  0.0388
# 2008-01-07 21:00:00+00:00                  0.0386
# 2008-01-08 21:00:00+00:00                  0.0386
#
# [5 rows x 39 columns]

# %%
# %pylab inline
figsize(12, 12)
# import matplotlib.pyplot as plt

# plt.plot(perf.index, perf.AAPL, 'r', perf.index, perf.portfolio_value)
ax1 = plt.subplot(211)
perf.portfolio_value.plot(ax=ax1)
ax1.set_ylabel('portfolio value')
ax2 = plt.subplot(212, sharex=ax1)
perf.AAPL.plot(ax=ax2)
ax2.set_ylabel('AAPL stock price')
# Out:
# Populating the interactive namespace from numpy and matplotlib
